# %%
import sys
import os
import numpy as np
from matplotlib import pyplot as plt

# Añadir el path del módulo hermano
sys.path.append(os.path.abspath('..'))

# Ahora puedes importar
from utils.CustomMorphOps import bresenham_line

# %%
white_canvas = np.ones((100, 100), dtype=np.float64) * 255.0

# %%
coords = bresenham_line(0,0,80,80,white_canvas.shape[0], white_canvas.shape[1], 0.5)

# %%
for x, y in coords:
    white_canvas[x,y] = 0

# %%
plt.imshow(white_canvas, cmap="gray", vmin=0, vmax=255)
plt.show()
